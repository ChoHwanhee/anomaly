# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd drive/MyDrive/Anomaly
# Out:
# /content/drive/MyDrive/Anomaly

# %%
# !pip install pytorch_model_summary
# !pip install einops

# %%
# !python train.py --save_interval=1000 --val_interval=1000
# Out:
# cuda
#
# ------------------------------train cfg------------------------------
# mode: train
# dataset: ped2
# img_size: (256, 256)
# data_root: data/
# batch_size: 4
# train_data: data/ped2/training/frames/
# test_data: data/ped2/testing/frames/
# g_lr: 0.0002
# d_lr: 2e-05
# resume: None
# iters: 40000
# save_interval: 1000
# val_interval: 1000
# manualseed: -1
# epoch_size: 10000
#
#
# ...
# Dataloader Ok!
# -----------------------------------------------------------
# [Data Size]: 16
# [Batch Size]: 4
# [One epoch]: 4 step   # (Data Size / Batch Size)
# [Epoch & Iteration]: 10000 epoch & 40000 step
# -----------------------------------------------------------
# ...
#
# ...
# Training Start!
# ...
# ===========epoch:5 (step:20)============
# [20] G_l: 0.137 | D_l: 0.242 | psnr: 21.754 | best_auc: 0.000 | iter_t: 1.320s | remain_t: 14:39:32
# ===========epoch:10 (step:40)============
# [40] G_l: 0.902 | D_l: 0.215 | psnr: 24.090 | best_auc: 0.000 | iter_t: 1.316s | remain_t: 14:36:45
# ...

# %% [markdown]
# 1
